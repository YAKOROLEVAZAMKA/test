# %%
import configparser
import unittest
import datetime
import sys
import pandas as pd

# from tqdm import tqdm_notebook

sys.path.append("/home/sergey/drclinics/common")
from universal_connection import UniversalConnection, DBType

sys.path.append("/home/sergey/drclinics/reports")
from report_utils import excel_report

import numpy as np
from log import log

# %%
sql = """
select
    DATE(a.finished + 3 * interval '1 hour'),
    'CHAT' in (
        select reference.code
        from appointment_connection_type
        left join reference on reference.id = appointment_connection_type.reference_id
        where a.id = appointment_connection_type.appointment_id
        ) as is_chat,
    'VIDEO' in (
        select reference.code
        from appointment_connection_type
        left join reference on reference.id = appointment_connection_type.reference_id
        where a.id = appointment_connection_type.appointment_id
        ) as is_video,
    'AUDIO' in (
        select reference.code
        from appointment_connection_type
        left join reference on reference.id = appointment_connection_type.reference_id
        where a.id = appointment_connection_type.appointment_id
        ) as is_audio,
    'PHONE' in (
        select reference.code
        from appointment_connection_type
        left join reference on reference.id = appointment_connection_type.reference_id
        where a.id = appointment_connection_type.appointment_id
        ) as is_phone,
    "source",
    case
        when pe.partner_id in (
            select id from partner
            where name = 'МК Доктор рядом'
            )
        then 'self'
        else 'external'
    end doctor_org,
    case
        when p.description_tsvector = 'телемедицина_вэб' then 'VEBMED'
        else 'ПРОЧИЕ'
    end promo_type,
    person.phone 
    -- DEBUG
    --, a.*
from appointment a
left join promotion p on a.promotion_id = p.id
left join product_condition pc on pc.id = p.product_condition_id
left join doctor d on d.id = a.doctor_id
left join person pe on pe.id = d.person_id
left join patient on a.patient_id = patient.id 
left join person on patient.person_id = person.id
where
-- DEBUG
-- a.finished at time zone 'UTC' between '2020-04-02' and '2020-04-02 19:00:00'
   a.finished at time zone 'UTC' > '2020-03-30'
  and a.good
  and not (
    a.patient_id in (
        select patient_id
        from patient_categories pcat
        inner join reference rf
           on rf.id=pcat.reference_id
        where rf.code='TEST'
        )
    or lower(a.report_comment)='тест'
    )
"""

# %%
connection = UniversalConnection('../../../.credentials/telemed/prom.cfg', DBType.Postgres)
# Out:
# 2020-04-17 13:13:10 connect to postgres database using config file "../../../.credentials/telemed/prom.cfg"
# 2020-04-17 13:13:10 creating ssh tunnel to 172.16.100.19 as root...
# 2020-04-17 13:13:37 connect postgres using parameters:
#                     database: telemed
# 				    user: norekhov
# 				    password: ***masked***
# 				    host: localhost
# 				    port: 38179
# 2020-04-17 13:13:37 @telemed: execute sql:
# 				    SET TIME ZONE 'Europe/Moscow'
# 				    None

# %%
data = connection.query(sql)
# Out:
# 2020-04-17 13:13:37 @telemed query:
#                     select
# 				        DATE(a.finished + 3 * interval '1 hour'),
# 				        'CHAT' in (
# 				            select reference.code
# 				            from appointment_connection_type
# 				            left join reference on reference.id = appointment_connection_type.reference_id
# 				            where a.id = appointment_connection_type.appointment_id
# 				            ) as is_chat,
# 				        'VIDEO' in (
# 				            select reference.code
# 				            from appointment_connection_type
# 				            left join reference on reference.id = appointment_connection_type.reference_id
# 				            where a.id = appointment_connection_type.appointment_id
# 				            ) as is_video,
# 				        'AUDIO' in (
# 				            select reference.code
# 				            from appointment_connection_type
# 				            left join reference on reference.id = appointment_connection_type.reference_id
# 				            where a.id = appointment_connection_type.appointment_id
# 				            ) as is_audio,
# 				        'PHONE' in (
# 				            select reference.code
# 				            from appointment_connection_type
# 				            left join reference on reference.id = appointment_connection_type.reference_id
# 				            where a.id = appointment_connection_type.appointment_id
# 				            ) as is_phone,
# 				        "source",
# 				        case
# 				            when pe.partner_id in (
# 				                select id from partner
# 				                where name = 'МК Доктор рядом'
# 				                )
# 				            then 'self'
# 				            else 'external'
# 				        end doctor_org,
# 				        case
# 				            when p.description_tsvector = 'телемедицина_вэб' then 'VEBMED'
# 				            else 'ПРОЧИЕ'
# 				        end promo_type,
# 				        person.phone
# 				        -- DEBUG
# 				        --, a.*
# 				    from appointment a
# 				    left join promotion p on a.promotion_id = p.id
# 				    left join product_condition pc on pc.id = p.product_condition_id
# 				    left join doctor d on d.id = a.doctor_id
# 				    left join person pe on pe.id = d.person_id
# 				    left join patient on a.patient_id = patient.id
# 				    left join person on patient.person_id = person.id
# 				    where
# 				    -- DEBUG
# 				    -- a.finished at time zone 'UTC' between '2020-04-02' and '2020-04-02 19:00:00'
# 				       a.finished at time zone 'UTC' > '2020-03-30'
# 				      and a.good
# 				      and not (
# 				        a.patient_id in (
# 				            select patient_id
# 				            from patient_categories pcat
# 				            inner join reference rf
# 				               on rf.id=pcat.reference_id
# 				            where rf.code='TEST'
# 				            )
# 				        or lower(a.report_comment)='тест'
# 				        )
#                     None
# 2020-04-17 13:13:38 return 16133 rows

# %%
connection.close()
# Out:
# 2020-04-17 13:13:38 @telemed: closing postgres connection...
# 2020-04-17 13:13:38 closing ssh tunnel to 172.16.100.19...

# %%
df = pd.DataFrame(data)

# %%
df.head()
# Out:
#          date  is_chat  is_video  is_audio  is_phone     source doctor_org  \
# 0  2020-04-08    False     False     False      True  SCHEDULED   external
# 1  2020-03-31     True     False     False     False     QUEUED       self
# 2  2020-04-15    False     False     False      True  SCHEDULED   external
# 3  2020-04-07    False     False     False      True     QUEUED   external
# 4  2020-03-31    False     False     False      True  SCHEDULED   external
#
#   promo_type        phone
# 0     ПРОЧИЕ  79091582287
# 1     VEBMED  79518565014
# 2     VEBMED  79687101977
# 3     ПРОЧИЕ  79089255484
# 4     ПРОЧИЕ  79180989263

# %%
def phone_base():
    base = pd.read_csv('DEF.csv')
    
    column_base = ['code', 'start', 'end', 'capacity', 'operator', 'region']
    base.columns = column_base
    
    return base

# %%
def get_region_by_phone(phone, base=phone_base()):
    if not phone:
        return 'Неизвестный регион'
    if type(phone) != str:
        phone = str(phone)
    phone = ''.join(i for i in phone if i.isdigit())    
    if phone[0] == '8' or phone[0] == '7':
        phone = phone[1:]
    if len(phone) != 10:
        return 'Неизвестный регион'
    return base.loc[(base['code'] == int(phone[0:3])) & 
                          (base['start'] <= int(phone[3:])) &
                          (base['end'] >= int(phone[3:]))
                         ]['region'].to_string(index=False).strip()

# %%
df['region'] = df['phone'].apply(get_region_by_phone)

# %%
df = df.replace('Series([], )', 'Неизвестный регион')

# %%
df
# Out:
#              date  is_chat  is_video  is_audio  is_phone     source  \
# 0      2020-04-08    False     False     False      True  SCHEDULED
# 1      2020-03-31     True     False     False     False     QUEUED
# 2      2020-04-15    False     False     False      True  SCHEDULED
# 3      2020-04-07    False     False     False      True     QUEUED
# 4      2020-03-31    False     False     False      True  SCHEDULED
# ...           ...      ...       ...       ...       ...        ...
# 16128  2020-04-16    False     False     False      True  SCHEDULED
# 16129  2020-04-16    False     False      True     False     QUEUED
# 16130  2020-04-16    False     False     False      True  SCHEDULED
# 16131  2020-04-16    False     False     False      True  SCHEDULED
# 16132  2020-04-17    False     False      True     False  SCHEDULED
#
#       doctor_org promo_type        phone                          region
# 0       external     ПРОЧИЕ  79091582287  г. Москва и Московская область
# 1           self     VEBMED  79518565014                Воронежская обл.
# 2       external     VEBMED  79687101977  г. Москва и Московская область
# 3       external     ПРОЧИЕ  79089255484               Свердловская обл.
# 4       external     ПРОЧИЕ  79180989263              Краснодарский край
# ...          ...        ...          ...                             ...
# 16128   external     ПРОЧИЕ  79268753130  г. Москва и Московская область
# 16129       self     VEBMED  79028197547    Ханты - Мансийский - Югра АО
# 16130   external     VEBMED  79618187336               Республика Адыгея
# 16131   external     VEBMED  79206741100                 Ивановская обл.
# 16132   external     VEBMED  79507241443                Челябинская обл.
#
# [16133 rows x 10 columns]

# %%
# df.to_excel('raw_data.xls')

# %%
df['consultation_type'] = ''

# %%
df.head()
# Out:
#          date  is_chat  is_video  is_audio  is_phone     source doctor_org  \
# 0  2020-04-08    False     False     False      True  SCHEDULED   external
# 1  2020-03-31     True     False     False     False     QUEUED       self
# 2  2020-04-15    False     False     False      True  SCHEDULED   external
# 3  2020-04-07    False     False     False      True     QUEUED   external
# 4  2020-03-31    False     False     False      True  SCHEDULED   external
#
#   promo_type        phone                          region consultation_type
# 0     ПРОЧИЕ  79091582287  г. Москва и Московская область
# 1     VEBMED  79518565014                Воронежская обл.
# 2     VEBMED  79687101977  г. Москва и Московская область
# 3     ПРОЧИЕ  79089255484               Свердловская обл.
# 4     ПРОЧИЕ  79180989263              Краснодарский край

# %%
for i in range(df.shape[0]):
    if df['is_video'][i]:
        df['consultation_type'][i] = 'video'
    elif df['is_audio'][i]:
        df['consultation_type'][i] = 'audio'
    elif df['is_chat'][i]:
        df['consultation_type'][i] = 'chat'
    else: # пожелание бизнеса!!!
        df['consultation_type'][i] = 'phone'
    #else:
    #    df['consultation_type'][i] = 'unknown'

# %%
df.head(25)
# Out:
#           date  is_chat  is_video  is_audio  is_phone     source doctor_org  \
# 0   2020-04-08    False     False     False      True  SCHEDULED   external
# 1   2020-03-31     True     False     False     False     QUEUED       self
# 2   2020-04-15    False     False     False      True  SCHEDULED   external
# 3   2020-04-07    False     False     False      True     QUEUED   external
# 4   2020-03-31    False     False     False      True  SCHEDULED   external
# 5   2020-04-07    False     False     False      True  SCHEDULED   external
# 6   2020-03-31    False     False      True     False     QUEUED   external
# 7   2020-03-31    False     False      True     False     ACTIVE       self
# 8   2020-04-07    False     False     False      True     QUEUED       self
# 9   2020-04-04     True     False     False     False  SCHEDULED   external
# 10  2020-03-31     True     False     False     False  SCHEDULED   external
# 11  2020-04-16    False     False     False      True  SCHEDULED   external
# 12  2020-04-08    False     False      True     False     QUEUED   external
# 13  2020-04-16    False     False     False      True  SCHEDULED   external
# 14  2020-04-16    False     False     False      True     QUEUED       self
# 15  2020-04-04    False     False     False      True  SCHEDULED   external
# 16  2020-04-07    False     False      True     False  SCHEDULED   external
# 17  2020-04-15    False     False     False      True  SCHEDULED   external
# 18  2020-04-16     True     False     False     False     QUEUED   external
# 19  2020-04-04    False     False      True     False  SCHEDULED   external
# 20  2020-04-07    False     False      True     False     QUEUED   external
# 21  2020-04-04    False     False      True     False  SCHEDULED   external
# 22  2020-04-11     True     False     False     False     QUEUED       self
# 23  2020-04-15    False     False      True     False  SCHEDULED   external
# 24  2020-04-08    False     False     False      True  SCHEDULED   external
#
#    promo_type        phone                                      region  \
# 0      ПРОЧИЕ  79091582287              г. Москва и Московская область
# 1      VEBMED  79518565014                            Воронежская обл.
# 2      VEBMED  79687101977              г. Москва и Московская область
# 3      ПРОЧИЕ  79089255484                           Свердловская обл.
# 4      ПРОЧИЕ  79180989263                          Краснодарский край
# 5      VEBMED  79911116364                         Ставропольский край
# 6      ПРОЧИЕ  79149123969                              Иркутская обл.
# 7      ПРОЧИЕ  79002066203                           Свердловская обл.
# 8      ПРОЧИЕ  79172240600                        Республика Татарстан
# 9      VEBMED  79166063464              г. Москва и Московская область
# 10     ПРОЧИЕ  79608725544                          Волгоградская обл.
# 11     VEBMED  79107992557                          Нижегородская обл.
# 12     ПРОЧИЕ  79031557720              г. Москва и Московская область
# 13     VEBMED  79218690506  г. Санкт-Петербург и Ленинградская область
# 14     VEBMED  79111751102  г. Санкт-Петербург и Ленинградская область
# 15     VEBMED  79961077203                     Республика Башкортостан
# 16     ПРОЧИЕ  79857143114              г. Москва и Московская область
# 17     VEBMED  79166373569              г. Москва и Московская область
# 18     ПРОЧИЕ  79050271273                        Чувашская Республика
# 19     ПРОЧИЕ  79200514141                          Нижегородская обл.
# 20     VEBMED  79057107789              г. Москва и Московская область
# 21     VEBMED  79279526635                     Республика Башкортостан
# 22     ПРОЧИЕ  79376418854                              Самарская обл.
# 23     VEBMED  79531032208                          Краснодарский край
# 24     VEBMED  79960277552                             Ивановская обл.
#
#    consultation_type
# 0              phone
# 1               chat
# 2              phone
# 3              phone
# 4              phone
# 5              phone
# 6              audio
# 7              audio
# 8              phone
# 9               chat
# 10              chat
# 11             phone
# 12             audio
# 13             phone
# 14             phone
# 15             phone
# 16             audio
# 17             phone
# 18              chat
# 19             audio
# 20             audio
# 21             audio
# 22              chat
# 23             audio
# 24             phone

# %%
df.consultation_type.unique()
# Out:
# array(['phone', 'chat', 'audio', 'video'], dtype=object)

# %%
#df.loc[1]['consultation_type']

# %%
df_group = df.groupby(['date','region', 'promo_type', 'consultation_type'])['source'].count().to_frame().reset_index().rename(columns={'source':'quantity'})

# %%
df_group.head(10)
# Out:
#          date             region promo_type consultation_type  quantity
# 0  2020-03-30     Алтайский край     ПРОЧИЕ             audio         2
# 1  2020-03-30     Алтайский край     ПРОЧИЕ              chat         1
# 2  2020-03-30     Алтайский край     ПРОЧИЕ             phone         1
# 3  2020-03-30      Амурская обл.     ПРОЧИЕ             audio         1
# 4  2020-03-30      Амурская обл.     ПРОЧИЕ             phone         1
# 5  2020-03-30  Астраханская обл.     ПРОЧИЕ             audio         1
# 6  2020-03-30  Белгородская обл.     ПРОЧИЕ             audio         1
# 7  2020-03-30  Белгородская обл.     ПРОЧИЕ              chat         4
# 8  2020-03-30  Белгородская обл.     ПРОЧИЕ             phone         3
# 9  2020-03-30  Владимирская обл.     ПРОЧИЕ             audio         1

# %%
#df[(df['date'] == df_group.loc[0]['date']) & (df['region'] == 'Алтайский край')]

# %%
#df[df['region'] == 'Ивановская обл.']

# %%
#df.groupby(['date','region', 'promo_type', 'is_chat', 'is_video', 'is_audio', 'is_phone'])['phone'].count().to_frame().reset_index()

# %%
#d3 = dict()

# %%
#dates = [date for date in df.date.unique()]
#dates.sort()

# %%
file_name = 'regions-consultation_type.xls'
writer = pd.ExcelWriter(file_name, engine='xlsxwriter')
df.to_excel(writer, sheet_name='Raw_data', index=False)
df_group.to_excel(writer, sheet_name='Group_by', index=False)

writer.save()
